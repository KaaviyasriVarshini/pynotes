# %%
import keyword

print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
x = 10
assert x > 0

# %%
score = 40
assert score >= 50, "Score must be at least 50 to pass"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[7], line 2
#       1 score = 40
# ----> 2 assert score >= 50, "Score must be at least 50 to pass"
#
# AssertionError: Score must be at least 50 to pass

# %%
pip show requests
# Out:
# Name: requests
# Version: 2.32.5
# Summary: Python HTTP for Humans.
# Home-page: https://requests.readthedocs.io
# Author: Kenneth Reitz
# Author-email: me@kennethreitz.org
# License: Apache-2.0
# Location: /home/sanjju/miniconda3/envs/py311/lib/python3.11/site-packages
# Requires: certifi, charset_normalizer, idna, urllib3
# Required-by: deepl, google-genai, id, jupyterlab_server, kubernetes, langchain-classic, langchain-community, langchainhub, langsmith, pinecone-text, posthog, requests-oauthlib, requests-toolbelt, tavily-python, tiktoken, twine
# Note: you may need to restart the kernel to use updated packages.

# %%
class Person:
    pass

p1 = Person()
print(p1)
# Out:
# <__main__.Person object at 0x7f1229f432d0>

# %%
class Student:
    school = "Global Academy"  # Class variable

    def __init__(self, name):
        self.name = name        # Instance variable

s1 = Student("Alice")
s2 = Student("Bob")

print(s1.school)
print(s2.school)
# Out:
# Global Academy
# Global Academy

# %%
class Animal:
    def sound(self):
        print("Some sound")

class Dog(Animal):
    def bark(self):
        print("Dog barks")

d = Dog()
d.sound()
d.bark()
# Out:
# Some sound
# Dog barks

# %%
class Grandparent:
    def feature(self):
        print("Grandparent feature")

class Parent(Grandparent):
    pass

class Child(Parent):
    pass

c = Child()
c.feature()
# Out:
# Grandparent feature

# %%
class Vehicle:
    def start(self):
        print("Vehicle started")

class Car(Vehicle):
    def drive(self):
        print("Car is driving")

class Bike(Vehicle):
    def ride(self):
        print("Bike is riding")

car = Car()
bike = Bike()

car.start()
car.drive()

bike.start()
bike.ride()
# Out:
# Vehicle started
# Car is driving
# Vehicle started
# Bike is riding

# %%
class A:
    def show(self):
        print("A")

class B:
    def show(self):
        print("B")

class C(A, B):
    pass

print(C.mro())
# Out:
# [<class '__main__.C'>, <class '__main__.A'>, <class '__main__.B'>, <class 'object'>]

# %%
class A:
    def __init__(self):
        print("A init")
        super().__init__()

class B:
    def __init__(self):
        print("B init")
        super().__init__()

class C(A, B):
    def __init__(self):
        print("C init")
        super().__init__()

c = C()
# Out:
# C init
# A init
# B init

# %%
class Grandparent:
    def greet(self):
        print("Hello from Grandparent")

class Parent1(Grandparent):
    pass

class Parent2(Grandparent):
    pass

class Child(Parent1, Parent2):
    pass

c = Child()
c.greet()
# Out:
# Hello from Grandparent

# %%
class X:
    pass

class Y(X):
    pass

class Z(X):
    pass

class W(Y, Z):
    pass

print(W.mro())
# Out:
# [<class '__main__.W'>, <class '__main__.Y'>, <class '__main__.Z'>, <class '__main__.X'>, <class 'object'>]

# %%
print(len("Python"))   # String length
print(len([1, 2, 3]))  # List length
# Out:
# 6
# 3

# %%
class Product:
    def __init__(self, name, price):
        self.name = name
        self.price = price

    def __str__(self):
        return f"{self.name} costs ${self.price}"

p = Product("Laptop", 1200)
print(p)  # Laptop costs $1200
# Out:
# Laptop costs $1200

# %%
import datetime

print(datetime.datetime.now())
# Out:
# 2026-03-02 19:55:04.952928

# %%
from datetime import datetime

now = datetime.now()

print(now.year)
print(now.month)
print(now.day)
print(now.hour)
print(now.minute)
print(now.second)
# Out:
# 2026
# 3
# 2
# 19
# 58
# 38

# %%
from datetime import date, time

d = date(2025, 6, 15)
t = time(14, 30, 45)

print(d)
print(t)
# Out:
# 2025-06-15
# 14:30:45

# %%
from datetime import datetime, timedelta

start = datetime.now()
end = start + timedelta(hours=5, minutes=30)

print("Start:", start)
print("End:", end)
# Out:
# Start: 2026-03-02 20:04:00.785967
# End: 2026-03-03 01:34:00.785967

# %%
from datetime import datetime, timedelta

meeting_time = datetime.now() + timedelta(days=2)

if datetime.now() < meeting_time:
    print("Meeting scheduled")
else:
    print("Meeting overdue")
# Out:
# Meeting scheduled
