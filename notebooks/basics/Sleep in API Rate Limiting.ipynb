# %%
import time

def api_request():
    print("Request sent")
    time.sleep(1)

for _ in range(5):
    api_request()
# Out:
# Request sent
# Request sent
# Request sent
# Request sent
# Request sent
