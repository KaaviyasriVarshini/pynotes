# %%
import pandas as pd

df = pd.read_csv("data.csv")

print(df)
print(df["Name"])
# Out:
#     Name  Age      Role
# 0  Alice   23  Engineer
# 1    Bob   30  Designer
# 0    Alice
# 1      Bob
# Name: Name, dtype: object
