# %%
import time

def process_batches():
    for batch in range(1, 4):
        print(f"Processing batch {batch}")
        time.sleep(2)

process_batches()
# Out:
# Processing batch 1
# Processing batch 2
# Processing batch 3
