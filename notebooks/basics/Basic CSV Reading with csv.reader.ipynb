# %%
import csv

with open("data.csv", "r") as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['Name', 'Age', 'Role']
# ['Alice', '23', 'Engineer']
# ['Bob', '30', 'Designer']
