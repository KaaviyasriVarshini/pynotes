# %%
def greet(name, age):
    print(f"{name} is {age} years old")

data = ("Alice", 30)
greet(*data)

info = {"name": "Bob", "age": 25}
greet(**info)
# Out:
# Alice is 30 years old
# Bob is 25 years old
