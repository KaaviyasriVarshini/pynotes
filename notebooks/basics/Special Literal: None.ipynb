# %%
result = None

if result is None:
    print("No value assigned yet")
# Out:
# No value assigned yet

# %%
result = 3

if result is None:
    print("No value assigned yet")
else:
    print(result)
# Out:
# 3
