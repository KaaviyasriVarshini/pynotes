# %%
items = ["pen", "pencil", "eraser"]
items[1] = "marker"

print(items)  # Output: ['pen', 'marker', 'eraser']
# Out:
# ['pen', 'marker', 'eraser']

# %%
items = ["pen", "pencil", "eraser"]
print(items)
items[1] = "marker"

print(items)  # Output: ['pen', 'marker', 'eraser']
# Out:
# ['pen', 'pencil', 'eraser']
# ['pen', 'marker', 'eraser']
