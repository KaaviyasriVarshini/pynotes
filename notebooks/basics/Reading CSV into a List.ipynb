# %%
import csv

with open("data.csv", "r") as file:
    reader = csv.reader(file)
    data = list(reader)

print(data)
# Out:
# [['Name', 'Age', 'Role'], ['Alice', '23', 'Engineer'], ['Bob', '30', 'Designer']]
