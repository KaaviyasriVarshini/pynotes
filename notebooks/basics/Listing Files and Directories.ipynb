# %%
import os

items = os.listdir(".")
print(items)
# Out:
# ['Collection Literals.ipynb', ' for Loop with else Clause.ipynb', 'Local vs Global Variable Conflict.ipynb', 'Common String Methods.ipynb', 'Using Variables in Expressions.ipynb', 'Production-Ready Main Template.ipynb', 'Untitled2.ipynb', 'String Formatting with Old-Style % Operator.ipynb', 'Bitwise Operators.ipynb', 'List Comprehension.ipynb', 'String Slicing.ipynb', 'Breaking Based on User Input.ipynb', 'Automatic Removal of Duplicates.ipynb', 'Using pass in a Class Definition.ipynb', 'Recursive String Reversal.ipynb', 'Creating a Tuple.ipynb', 'Using range() in for Loop.ipynb', 'Main Function with Parameters.ipynb', 'Slicing Lists.ipynb', 'Converting Between Tuples and Lists.ipynb', 'List Length and Membership.ipynb', 'Using Main with Command-Line Arguments.ipynb', 'Using pass in Conditional Blocks.ipynb', 'Using break to Exit a Loop Early.ipynb', 'Converting Input to Required Data Type.ipynb', 'Multiple Variable Assignment.ipynb', 'Recursion vs Iteration Comparison.ipynb', 'Strin
# ...
