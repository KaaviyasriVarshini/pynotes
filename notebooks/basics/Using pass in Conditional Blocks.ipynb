# %%
score = 85

if score > 90:
    print("Excellent")
elif score > 80:
    pass
else:
    print("Needs Improvement")

# %%
score = 99

if score > 90:
    print("Excellent")
elif score > 80:
    pass
else:
    print("Needs Improvement")
# Out:
# Excellent
