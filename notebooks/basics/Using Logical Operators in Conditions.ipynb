# %%
age = 25
is_verified = True

if age > 18 and is_verified:
    print("User can proceed")
# Out:
# User can proceed

# %%
age = 15
is_verified = True

if age > 18 and is_verified:
    print("User can proceed")
else:
    print("Stop")
# Out:
# Stop
